# %% [markdown]
# # Day 08. Exercise 00
# # Binary classifier. Logistic regression

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# - Get the data from the file [`checker-timestamp.csv`](https://drive.google.com/file/d/1pooM4cITtG249msX3GK_6W0eEiblzAf5/view?usp=sharing).
#
#
# - Create a dataframe `df` with the columns: `date`, `am`, `pm`, `target`, where `date` is the date of the day, `am` is the number of the commits during the day before midday (integer), `pm` is the number of commits during the day after midday (integer), `target` is weekend/working_day.

# %% [markdown]
# ## Get the data from the file checker-timestamp.csv.

# %%
df = pd.read_csv('../data/checker_timestamp.csv')

# %% [markdown]
# ## Create a dataframe df with the columns: date, am, pm, target, where date is the date of the day, am is the number of the commits during the day before midday (integer), pm is the number of commits during the day after midday (integer), target is weekend/working_day.

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df['date'] = df['timestamp'].dt.date

# %%
df['hour'] = df['timestamp'].dt.hour

# %%
df['am'] = (df['hour'] < 12).astype(int)

# %%
df['pm'] = (df['hour'] >= 12).astype(int)

# %%
df['target'] = (df['timestamp'].dt.dayofweek >= 5).astype(int)

# %%
df
# Out:
#                       timestamp        date  hour  am  pm  target
# 0    2020-04-17 05:19:02.744528  2020-04-17     5   1   0       0
# 1    2020-04-17 05:22:35.249331  2020-04-17     5   1   0       0
# 2    2020-04-17 05:22:45.549397  2020-04-17     5   1   0       0
# 3    2020-04-17 05:34:14.691200  2020-04-17     5   1   0       0
# 4    2020-04-17 05:34:24.422370  2020-04-17     5   1   0       0
# ...                         ...         ...   ...  ..  ..     ...
# 3202 2020-05-21 20:19:06.872761  2020-05-21    20   0   1       0
# 3203 2020-05-21 20:22:41.785725  2020-05-21    20   0   1       0
# 3204 2020-05-21 20:22:41.877806  2020-05-21    20   0   1       0
# 3205 2020-05-21 20:37:00.129678  2020-05-21    20   0   1       0
# 3206 2020-05-21 20:37:00.290491  2020-05-21    20   0   1       0
#
# [3207 rows x 6 columns]

# %%
df = df.drop(['timestamp', 'hour'], axis=1)

# %%
df
# Out:
#             date  am  pm  target
# 0     2020-04-17   1   0       0
# 1     2020-04-17   1   0       0
# 2     2020-04-17   1   0       0
# 3     2020-04-17   1   0       0
# 4     2020-04-17   1   0       0
# ...          ...  ..  ..     ...
# 3202  2020-05-21   0   1       0
# 3203  2020-05-21   0   1       0
# 3204  2020-05-21   0   1       0
# 3205  2020-05-21   0   1       0
# 3206  2020-05-21   0   1       0
#
# [3207 rows x 4 columns]

# %%
df = df.groupby(by='date').agg({ 'am': 'sum',
                                'pm': 'sum',
                                'target':'first'})

# %%
df
# Out:
#             am   pm  target
# date
# 2020-04-17  21    2       0
# 2020-04-18   1   68       1
# 2020-04-19  18   15       1
# 2020-04-20   2   23       0
# 2020-04-21   0   25       0
# 2020-04-22   0   28       0
# 2020-04-23  10   33       0
# 2020-04-24   2   14       0
# 2020-04-25  30   74       1
# 2020-04-26  28  233       1
# 2020-04-27   4    2       0
# 2020-04-28   4    1       0
# 2020-04-29   0   17       0
# 2020-04-30  13   40       0
# 2020-05-01   8   52       0
# 2020-05-02  91  151       1
# 2020-05-03  47  133       1
# 2020-05-04  11   26       0
# 2020-05-05  81   58       0
# 2020-05-06   2    0       0
# 2020-05-07  14   38       0
# 2020-05-08   3   84       0
# 2020-05-09   0   86       1
# 2020-05-10  10  133       1
# 2020-05-11   3  183       0
# 2020-05-12  56  267       0
# 2020-05-13   6  205       0
# 2020-05-14  66  509       0
# 2020-05-15  10    0       0
# 2020-05-16   0    4       1
# 2020-05-17   2   46       1
# 2020-05-18   0    3       0
# 2020-05-19  20   14       0
# 2020-05-20   7   21       0
# 2020-05-21   1   48       0

# %% [markdown]
# ## 2. Exploratory analysis

# %% [markdown]
# - Create a plot where `x` is am, `y` is pm, each dot is a day, working days and weekends must have different colors.
#
#
# - By looking at the graph do you think it will be easy to classify the days having those two features? Put your answer in the markdown cell in the end of that sectioin: "yes, it is easy" or "no, it is not easy".

# %%
plt.scatter(df['am'], df['pm'], c=df['target'])

# %% [markdown]
# ## By looking at the graph do you think it will be easy to classify the days having those two features?

# %% [markdown]
# Answer: no, it is not easy.

# %% [markdown]
# ## 3. Logistic regression

# %% [markdown]
# - Train logistic regression on your data using `am` and `pm`, parameters are: `random state=21`, `fit_intercept=False`.
#
#
# - Make predictions for every day of your dataset and add them to your dataframe with the column name `predict`.
#
#
# - Save the dataframe into a file in the subfolder of the day `data` with the name `am_pm.csv`.
#
#
# - Draw another plot like you did before, but the color should be taken from the `predict`.
#
#
# - By looking at the graph do you think if it made good predictions? Put your answer in the markdown cell in the end of that section: "yes, it is good"; "no, it is not good".

# %% [markdown]
# ## Train logistic regression on your data using am and pm, parameters are: random state=21, fit_intercept=False.

# %%
df
# Out:
#             am   pm  target
# date
# 2020-04-17  21    2       0
# 2020-04-18   1   68       1
# 2020-04-19  18   15       1
# 2020-04-20   2   23       0
# 2020-04-21   0   25       0
# 2020-04-22   0   28       0
# 2020-04-23  10   33       0
# 2020-04-24   2   14       0
# 2020-04-25  30   74       1
# 2020-04-26  28  233       1
# 2020-04-27   4    2       0
# 2020-04-28   4    1       0
# 2020-04-29   0   17       0
# 2020-04-30  13   40       0
# 2020-05-01   8   52       0
# 2020-05-02  91  151       1
# 2020-05-03  47  133       1
# 2020-05-04  11   26       0
# 2020-05-05  81   58       0
# 2020-05-06   2    0       0
# 2020-05-07  14   38       0
# 2020-05-08   3   84       0
# 2020-05-09   0   86       1
# 2020-05-10  10  133       1
# 2020-05-11   3  183       0
# 2020-05-12  56  267       0
# 2020-05-13   6  205       0
# 2020-05-14  66  509       0
# 2020-05-15  10    0       0
# 2020-05-16   0    4       1
# 2020-05-17   2   46       1
# 2020-05-18   0    3       0
# 2020-05-19  20   14       0
# 2020-05-20   7   21       0
# 2020-05-21   1   48       0

# %%
X = df[['am', 'pm']]

# %%
y = df['target']

# %%
X
# Out:
#             am   pm
# date
# 2020-04-17  21    2
# 2020-04-18   1   68
# 2020-04-19  18   15
# 2020-04-20   2   23
# 2020-04-21   0   25
# 2020-04-22   0   28
# 2020-04-23  10   33
# 2020-04-24   2   14
# 2020-04-25  30   74
# 2020-04-26  28  233
# 2020-04-27   4    2
# 2020-04-28   4    1
# 2020-04-29   0   17
# 2020-04-30  13   40
# 2020-05-01   8   52
# 2020-05-02  91  151
# 2020-05-03  47  133
# 2020-05-04  11   26
# 2020-05-05  81   58
# 2020-05-06   2    0
# 2020-05-07  14   38
# 2020-05-08   3   84
# 2020-05-09   0   86
# 2020-05-10  10  133
# 2020-05-11   3  183
# 2020-05-12  56  267
# 2020-05-13   6  205
# 2020-05-14  66  509
# 2020-05-15  10    0
# 2020-05-16   0    4
# 2020-05-17   2   46
# 2020-05-18   0    3
# 2020-05-19  20   14
# 2020-05-20   7   21
# 2020-05-21   1   48

# %%
y
# Out:
# date
# 2020-04-17    0
# 2020-04-18    1
# 2020-04-19    1
# 2020-04-20    0
# 2020-04-21    0
# 2020-04-22    0
# 2020-04-23    0
# 2020-04-24    0
# 2020-04-25    1
# 2020-04-26    1
# 2020-04-27    0
# 2020-04-28    0
# 2020-04-29    0
# 2020-04-30    0
# 2020-05-01    0
# 2020-05-02    1
# 2020-05-03    1
# 2020-05-04    0
# 2020-05-05    0
# 2020-05-06    0
# 2020-05-07    0
# 2020-05-08    0
# 2020-05-09    1
# 2020-05-10    1
# 2020-05-11    0
# 2020-05-12    0
# 2020-05-13    0
# 2020-05-14    0
# 2020-05-15    0
# 2020-05-16    1
# 2020-05-17    1
# 2020-05-18    0
# 2020-05-19    0
# 2020-05-20    0
# 2020-05-21    0
# Name: target, dtype: int64

# %%
lr = LogisticRegression(random_state=21, fit_intercept=False)

# %%
lr.fit(X, y)
# Out:
# LogisticRegression(fit_intercept=False, random_state=21)

# %% [markdown]
# ## Make predictions for every day of your dataset and add them to your dataframe with the column name predict.

# %%
df['predict'] = lr.predict(X)

# %%
df
# Out:
#             am   pm  target  predict
# date
# 2020-04-17  21    2       0        1
# 2020-04-18   1   68       1        0
# 2020-04-19  18   15       1        0
# 2020-04-20   2   23       0        0
# 2020-04-21   0   25       0        0
# 2020-04-22   0   28       0        0
# 2020-04-23  10   33       0        0
# 2020-04-24   2   14       0        0
# 2020-04-25  30   74       1        0
# 2020-04-26  28  233       1        0
# 2020-04-27   4    2       0        0
# 2020-04-28   4    1       0        0
# 2020-04-29   0   17       0        0
# 2020-04-30  13   40       0        0
# 2020-05-01   8   52       0        0
# 2020-05-02  91  151       1        0
# 2020-05-03  47  133       1        0
# 2020-05-04  11   26       0        0
# 2020-05-05  81   58       0        0
# 2020-05-06   2    0       0        1
# 2020-05-07  14   38       0        0
# 2020-05-08   3   84       0        0
# 2020-05-09   0   86       1        0
# 2020-05-10  10  133       1        0
# 2020-05-11   3  183       0        0
# 2020-05-12  56  267       0        0
# 2020-05-13   6  205       0        0
# 2020-05-14  66  509       0        0
# 2020-05-15  10    0       0        1
# 2020-05-16   0    4       1        0
# 2020-05-17   2   46       1        0
# 2020-05-18   0    3       0        0
# 2020-05-19  20   14       0        0
# 2020-05-20   7   21       0        0
# 2020-05-21   1   48       0        0

# %% [markdown]
# ## Save the dataframe into a file in the subfolder of the day data with the name am_pm.csv.

# %%
df.to_csv('../data/am_pm.csv')

# %% [markdown]
# ## Draw another plot like you did before, but the color should be taken from the predict.

# %%
plt.scatter(df['am'], df['pm'], c=df['predict'])

# %% [markdown]
# ## By looking at the graph do you think if it made good predictions?

# %% [markdown]
# Answer: no, it is not good.

# %% [markdown]
# ## 4. Evaluation

# %% [markdown]
# - Calculate `accuracy` for your predictions.
#
#
# - Calculate `accuracy` for the naive case when each of your prediction is the value of your most popular class of the day.
#
#
# - Comparing the accuracies do you think that the classifier made good predictions? Put your answer in the markdown cell in the end of the secion: "yes, it is good"; "no, it is not good".

# %% [markdown]
# ## Calculate `accuracy` for your predictions.

# %%
accuracy_score(df['target'], df['predict'])
# Out:
# 0.6285714285714286

# %% [markdown]
# ## Calculate `accuracy` for the naive case when each of your prediction is the value of your most popular class of the day.

# %%
accuracy_score(df['target'], [df['target'].mode()[0]] * len(df['target']))
# Out:
# 0.7142857142857143

# %% [markdown]
# ## Comparing the accuracies do you think that the classifier made good predictions?

# %% [markdown]
# Answer: no, it is not good.
