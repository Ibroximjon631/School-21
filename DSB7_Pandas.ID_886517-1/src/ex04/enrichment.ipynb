# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## read the JSON file that you saved in ex02

# %%
df = pd.read_json('../ex02/auto.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CarNumber  725 non-null    object
#  1   Refund     725 non-null    int64
#  2   Fines      725 non-null    float64
#  3   Make       725 non-null    object
#  4   Model      716 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 28.4+ KB

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df
# Out:
#         CarNumber  Refund    Fines    Make    Model
# 0    Y163O8161RUS       2  3200.00    Ford    Focus
# 1     E432XX77RUS       1  6500.00  Toyota    Camry
# 2     7184TT36RUS       1  2100.00    Ford    Focus
# 3    X582HE161RUS       2  2000.00    Ford    Focus
# 4    92918M178RUS       1  5700.00    Ford    Focus
# ..            ...     ...      ...     ...      ...
# 720  Y163O8161RUS       2  1600.00    Ford    Focus
# 721  M0309X197RUS       1 22300.00    Ford    Focus
# 722  O673E8197RUS       2   600.00    Ford    Focus
# 723  8610T8154RUS       1  2000.00    Ford    Focus
# 724  H419XE197RUS       2  8594.59  Toyota  Corolla
#
# [725 rows x 5 columns]

# %% [markdown]
# ## enrich the dataframe using a sample from that dataframe

# %%
sample_df = df.sample(200, random_state=21)

# %%
concat_rows = pd.concat([df, sample_df])

# %%
concat_rows.index = range(len(concat_rows))

# %%
concat_rows
# Out:
#         CarNumber  Refund   Fines        Make   Model
# 0    Y163O8161RUS       2 3200.00        Ford   Focus
# 1     E432XX77RUS       1 6500.00      Toyota   Camry
# 2     7184TT36RUS       1 2100.00        Ford   Focus
# 3    X582HE161RUS       2 2000.00        Ford   Focus
# 4    92918M178RUS       1 5700.00        Ford   Focus
# ..            ...     ...     ...         ...     ...
# 920  8182XX154RUS       1  200.00        Ford   Focus
# 921   X796TH96RUS       1  500.00        Ford   Focus
# 922  T011MY163RUS       2 4000.00        Ford   Focus
# 923   T341CC96RUS       2 1000.00  Volkswagen  Passat
# 924   T119CT96RUS       1 2000.00        Ford   Focus
#
# [925 rows x 5 columns]

# %% [markdown]
# ## enrich the dataframe concat_rows by a new column with the data generated

# %%
len(concat_rows)
# Out:
# 925

# %%
np.random.seed(21)
Year = np.random.randint(1980, 2019, len(concat_rows))
Year = pd.Series(Year, name='Year')

# %%
Year
# Out:
# 0      1989
# 1      1995
# 2      1984
# 3      2015
# 4      2014
#        ...
# 920    1996
# 921    2002
# 922    1996
# 923    2012
# 924    1984
# Name: Year, Length: 925, dtype: int64

# %%
fines = pd.concat([concat_rows, Year], axis=1)

# %%
fines
# Out:
#         CarNumber  Refund   Fines        Make   Model  Year
# 0    Y163O8161RUS       2 3200.00        Ford   Focus  1989
# 1     E432XX77RUS       1 6500.00      Toyota   Camry  1995
# 2     7184TT36RUS       1 2100.00        Ford   Focus  1984
# 3    X582HE161RUS       2 2000.00        Ford   Focus  2015
# 4    92918M178RUS       1 5700.00        Ford   Focus  2014
# ..            ...     ...     ...         ...     ...   ...
# 920  8182XX154RUS       1  200.00        Ford   Focus  1996
# 921   X796TH96RUS       1  500.00        Ford   Focus  2002
# 922  T011MY163RUS       2 4000.00        Ford   Focus  1996
# 923   T341CC96RUS       2 1000.00  Volkswagen  Passat  2012
# 924   T119CT96RUS       1 2000.00        Ford   Focus  1984
#
# [925 rows x 6 columns]

# %% [markdown]
# ## enrich the dataframe with the data from another dataframe

# %% [markdown]
# #### create a new dataframe with the car numbers and their owners

# %%
surname = pd.read_json('../../datasets/surname.json')

# %%
surname.columns = surname.iloc[0]

# %%
surname = surname[1:]

# %%
surname = surname.reset_index(drop=True)

# %%
surname
# Out:
# 0       NAME    COUNT RANK
# 0      ADAMS   427865   42
# 1      ALLEN   482607   33
# 2    ALVAREZ   233983   92
# 3   ANDERSON   784404   15
# 4     BAILEY   277845   72
# ..       ...      ...  ...
# 95  WILLIAMS  1625252    3
# 96    WILSON   801882   14
# 97      WOOD   250715   84
# 98    WRIGHT   458980   35
# 99     YOUNG   484447   32
#
# [100 rows x 3 columns]

# %%
unique_car_nums = concat_rows['CarNumber'].unique()

# %%
len(unique_car_nums)
# Out:
# 531

# %%
np.random_state = 21
surnames = pd.Series(np.random.choice(surname['NAME'], size=len(unique_car_nums)))
surnames
# Out:
# 0        TURNER
# 1      MARTINEZ
# 2          HALL
# 3          REED
# 4       SANCHEZ
#          ...
# 526       YOUNG
# 527       BROWN
# 528         COX
# 529        GRAY
# 530     ROBERTS
# Length: 531, dtype: object

# %%
owners = pd.DataFrame()

# %%
owners['CarNumber'] = unique_car_nums
owners['SURNAME'] = surnames
owners
# Out:
#         CarNumber   SURNAME
# 0    Y163O8161RUS    TURNER
# 1     E432XX77RUS  MARTINEZ
# 2     7184TT36RUS      HALL
# 3    X582HE161RUS      REED
# 4    92918M178RUS   SANCHEZ
# ..            ...       ...
# 526  O136HO197RUS     YOUNG
# 527  O22097197RUS     BROWN
# 528  M0309X197RUS       COX
# 529  O673E8197RUS      GRAY
# 530  8610T8154RUS   ROBERTS
#
# [531 rows x 2 columns]

# %% [markdown]
# #### append 5 more observations to the fines dataframe (come up with your own ideas of CarNumber, etc.)

# %%
fines
# Out:
#         CarNumber  Refund   Fines        Make   Model  Year
# 0    Y163O8161RUS       2 3200.00        Ford   Focus  1989
# 1     E432XX77RUS       1 6500.00      Toyota   Camry  1995
# 2     7184TT36RUS       1 2100.00        Ford   Focus  1984
# 3    X582HE161RUS       2 2000.00        Ford   Focus  2015
# 4    92918M178RUS       1 5700.00        Ford   Focus  2014
# ..            ...     ...     ...         ...     ...   ...
# 920  8182XX154RUS       1  200.00        Ford   Focus  1996
# 921   X796TH96RUS       1  500.00        Ford   Focus  2002
# 922  T011MY163RUS       2 4000.00        Ford   Focus  1996
# 923   T341CC96RUS       2 1000.00  Volkswagen  Passat  2012
# 924   T119CT96RUS       1 2000.00        Ford   Focus  1984
#
# [925 rows x 6 columns]

# %%
fines.loc[len(fines)] = ['FK7362JG322RUS', 1, 7200.00, 'Hyundai', 'Solaris', 2016]
fines.loc[len(fines)] = ['US738G728RUS', 1, 1800.00, 'Porsche', 'Cayenne', 2012]
fines.loc[len(fines)] = ['AA837YH192RUS', 1, 6500.00, 'Hyundai', 'Accent', 2010]
fines.loc[len(fines)] = ['GJ123H3P128RUS', 1, 7400.00, 'Lada', 'Granta', 2014]
fines.loc[len(fines)] = ['KP341H177RUS', 1, 9200.00, 'Ford', 'Focus', 2015]

# %% [markdown]
# #### delete the dataframe last 20 observations from the owners and add 3 new observations (they are not the same as those you add to the fines dataframe)

# %%
owners
# Out:
#         CarNumber   SURNAME
# 0    Y163O8161RUS    TURNER
# 1     E432XX77RUS  MARTINEZ
# 2     7184TT36RUS      HALL
# 3    X582HE161RUS      REED
# 4    92918M178RUS   SANCHEZ
# ..            ...       ...
# 526  O136HO197RUS     YOUNG
# 527  O22097197RUS     BROWN
# 528  M0309X197RUS       COX
# 529  O673E8197RUS      GRAY
# 530  8610T8154RUS   ROBERTS
#
# [531 rows x 2 columns]

# %%
owners = owners[:len(owners) - 20]

# %%
owners
# Out:
#         CarNumber   SURNAME
# 0    Y163O8161RUS    TURNER
# 1     E432XX77RUS  MARTINEZ
# 2     7184TT36RUS      HALL
# 3    X582HE161RUS      REED
# 4    92918M178RUS   SANCHEZ
# ..            ...       ...
# 506  T914CT197RUS      DIAZ
# 507  E41977152RUS     CLARK
# 508  9464EX178RUS     BAKER
# 509  O50197197RUS   ALVAREZ
# 510  7608EE777RUS      RUIZ
#
# [511 rows x 2 columns]

# %%
# owners.loc[len(owners)] = ['SJ0273Y61RUS', 'RODGERS']
# owners.loc[len(owners)] = ['AP321E161RUS', 'JHONSONS']
# owners.loc[len(owners)] = ['CS527Y161RUS', 'COOPERS']
new_rows = pd.DataFrame({
    'CarNumber': ['SJ0273Y61RUS', 'AP321E161RUS', 'CS527Y161RUS'],
    'SURNAME': ['RODGERS', 'JHONSONS', 'COOPERS']
})

owners = pd.concat([owners, new_rows], ignore_index=True)

# %%
owners
# Out:
#         CarNumber   SURNAME
# 0    Y163O8161RUS    TURNER
# 1     E432XX77RUS  MARTINEZ
# 2     7184TT36RUS      HALL
# 3    X582HE161RUS      REED
# 4    92918M178RUS   SANCHEZ
# ..            ...       ...
# 509  O50197197RUS   ALVAREZ
# 510  7608EE777RUS      RUIZ
# 511  SJ0273Y61RUS   RODGERS
# 512  AP321E161RUS  JHONSONS
# 513  CS527Y161RUS   COOPERS
#
# [514 rows x 2 columns]

# %% [markdown]
# #### join both dataframes

# %%
fines.head()
# Out:
#       CarNumber  Refund   Fines    Make  Model  Year
# 0  Y163O8161RUS       2 3200.00    Ford  Focus  1989
# 1   E432XX77RUS       1 6500.00  Toyota  Camry  1995
# 2   7184TT36RUS       1 2100.00    Ford  Focus  1984
# 3  X582HE161RUS       2 2000.00    Ford  Focus  2015
# 4  92918M178RUS       1 5700.00    Ford  Focus  2014

# %%
owners.head()
# Out:
#       CarNumber   SURNAME
# 0  Y163O8161RUS    TURNER
# 1   E432XX77RUS  MARTINEZ
# 2   7184TT36RUS      HALL
# 3  X582HE161RUS      REED
# 4  92918M178RUS   SANCHEZ

# %%
## the new dataframe should have only the car numbers that exist in both dataframes
pd.merge(fines, owners, on='CarNumber', how='inner')
# Out:
#         CarNumber  Refund    Fines    Make    Model  Year   SURNAME
# 0    Y163O8161RUS       2  3200.00    Ford    Focus  1989    TURNER
# 1    Y163O8161RUS       2  1600.00    Ford    Focus  1999    TURNER
# 2     E432XX77RUS       1  6500.00  Toyota    Camry  1995  MARTINEZ
# 3     E432XX77RUS       2 13000.00  Toyota    Camry  1992  MARTINEZ
# 4     7184TT36RUS       1  2100.00    Ford    Focus  1984      HALL
# ..            ...     ...      ...     ...      ...   ...       ...
# 894  E41977152RUS       2  2400.00    Ford    Focus  2001     CLARK
# 895  9464EX178RUS       2  2100.00    Ford    Focus  1993     BAKER
# 896  O50197197RUS       2  7800.00    Ford    Focus  1986   ALVAREZ
# 897  7608EE777RUS       1  4000.00   Skoda  Octavia  2013      RUIZ
# 898  7608EE777RUS       1  4000.00   Skoda  Octavia  1987      RUIZ
#
# [899 rows x 7 columns]

# %%
## the new dataframe should have all the car numbers that exist in both dataframes
pd.merge(fines, owners, on='CarNumber', how='outer')
# Out:
#           CarNumber  Refund    Fines    Make   Model    Year   SURNAME
# 0      Y163O8161RUS    2.00  3200.00    Ford   Focus 1989.00    TURNER
# 1      Y163O8161RUS    2.00  1600.00    Ford   Focus 1999.00    TURNER
# 2       E432XX77RUS    1.00  6500.00  Toyota   Camry 1995.00  MARTINEZ
# 3       E432XX77RUS    2.00 13000.00  Toyota   Camry 1992.00  MARTINEZ
# 4       7184TT36RUS    1.00  2100.00    Ford   Focus 1984.00      HALL
# ..              ...     ...      ...     ...     ...     ...       ...
# 928  GJ123H3P128RUS    1.00  7400.00    Lada  Granta 2014.00       NaN
# 929    KP341H177RUS    1.00  9200.00    Ford   Focus 2015.00       NaN
# 930    SJ0273Y61RUS     NaN      NaN     NaN     NaN     NaN   RODGERS
# 931    AP321E161RUS     NaN      NaN     NaN     NaN     NaN  JHONSONS
# 932    CS527Y161RUS     NaN      NaN     NaN     NaN     NaN   COOPERS
#
# [933 rows x 7 columns]

# %%
## the new dataframe should have only the car numbers from the fines dataframe
pd.merge(fines, owners, on='CarNumber', how='left')
# Out:
#           CarNumber  Refund   Fines     Make    Model  Year   SURNAME
# 0      Y163O8161RUS       2 3200.00     Ford    Focus  1989    TURNER
# 1       E432XX77RUS       1 6500.00   Toyota    Camry  1995  MARTINEZ
# 2       7184TT36RUS       1 2100.00     Ford    Focus  1984      HALL
# 3      X582HE161RUS       2 2000.00     Ford    Focus  2015      REED
# 4      92918M178RUS       1 5700.00     Ford    Focus  2014   SANCHEZ
# ..              ...     ...     ...      ...      ...   ...       ...
# 925  FK7362JG322RUS       1 7200.00  Hyundai  Solaris  2016       NaN
# 926    US738G728RUS       1 1800.00  Porsche  Cayenne  2012       NaN
# 927   AA837YH192RUS       1 6500.00  Hyundai   Accent  2010       NaN
# 928  GJ123H3P128RUS       1 7400.00     Lada   Granta  2014       NaN
# 929    KP341H177RUS       1 9200.00     Ford    Focus  2015       NaN
#
# [930 rows x 7 columns]

# %%
## the new dataframe should have only the car numbers from the owners dataframe
pd.merge(fines, owners, on='CarNumber', how='right')
# Out:
#         CarNumber  Refund    Fines    Make    Model    Year   SURNAME
# 0    Y163O8161RUS    2.00  3200.00    Ford    Focus 1989.00    TURNER
# 1    Y163O8161RUS    2.00  1600.00    Ford    Focus 1999.00    TURNER
# 2     E432XX77RUS    1.00  6500.00  Toyota    Camry 1995.00  MARTINEZ
# 3     E432XX77RUS    2.00 13000.00  Toyota    Camry 1992.00  MARTINEZ
# 4     7184TT36RUS    1.00  2100.00    Ford    Focus 1984.00      HALL
# ..            ...     ...      ...     ...      ...     ...       ...
# 897  7608EE777RUS    1.00  4000.00   Skoda  Octavia 2013.00      RUIZ
# 898  7608EE777RUS    1.00  4000.00   Skoda  Octavia 1987.00      RUIZ
# 899  SJ0273Y61RUS     NaN      NaN     NaN      NaN     NaN   RODGERS
# 900  AP321E161RUS     NaN      NaN     NaN      NaN     NaN  JHONSONS
# 901  CS527Y161RUS     NaN      NaN     NaN      NaN     NaN   COOPERS
#
# [902 rows x 7 columns]

# %% [markdown]
# ## create a pivot table from the fines dataframe, it should look like this (the values are the sums of the fines), but with all the years (the values may be different for you)

# %%
pd.pivot_table(fines, values='Fines', index=['Make', 'Model'], columns='Year', aggfunc='sum')
# Out:
# Year                   1980      1981      1982      1983      1984      1985  \
# Make       Model
# Ford       Focus   89194.59 266783.76 107283.76 147289.17 106000.00 307494.59
#            Mondeo       NaN       NaN  46200.00       NaN       NaN       NaN
# Hyundai    Accent       NaN       NaN       NaN       NaN       NaN       NaN
#            Solaris      NaN       NaN       NaN       NaN       NaN       NaN
# Lada       Granta       NaN       NaN       NaN       NaN       NaN       NaN
# Porsche    Cayenne      NaN       NaN       NaN       NaN       NaN       NaN
# Skoda      Octavia 13794.59   1900.00   8894.59       NaN   1300.00 153594.59
# Toyota     Camry   12000.00       NaN   1000.00   8594.59   1000.00       NaN
#            Corolla      NaN   6800.00       NaN  12800.00       NaN   4400.00
# Volkswagen Golf    20800.00   8594.59   5000.00    200.00       NaN 168000.00
#            Jetta        NaN   1000.00       NaN       NaN       NaN   9000.00
# ...

# %% [markdown]
# ## save both the fines and owners dataframes to CSV files without an index

# %%
fines.to_csv('fines.csv', index=None)
owners.to_csv('owners.csv', index=None)
